# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from IPython.display import Image
import StringIO, pydot
# %matplotlib inline

data = pd.read_csv('Cell2Cell_data.csv')
train_split = 0.8
train_index = random.sample(range(0,len(data)),int(len(data)*train_split))
test_index = list(set(range(0,len(data)))-set(train_index))
train_set = data.ix[train_index]
X_train = train_set[:]
del X_train['churndep']
Y_train = train_set['churndep']
test_set = data.ix[test_index]
X_test = test_set[:]
del X_test['churndep']
Y_test = test_set['churndep']
clf = DecisionTreeClassifier(criterion='entropy',min_samples_split=300, min_samples_leaf=500)
clf.fit(X_train,Y_train)
ans = clf.predict(X_test)
print float((len(ans)-sum(abs(ans-Y_test))))/len(ans)
fig = plt.figure()
width=0.35
ax = fig.add_subplot(111)
ax.bar(np.arange(11), clf.feature_importances_, width, color='r')
ax.set_xticks(np.arange(len(clf.feature_importances_)))
ax.set_xticklabels(X_test.columns,rotation=90)
plt.title('Feature Importance from DT')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 67
# 0.596588058204

# %%
data_3most = data[['revenue','eqpdays','outcalls']]
cor=data_3most.corr()

# %%
dot_data = StringIO.StringIO()
export_graphviz(clf, out_file=dot_data)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e939f438f713> in <module>()
#       1 dot_data = StringIO.StringIO()
#       2 export_graphviz(clf, out_file=dot_data)
# ----> 3 graph = pydot.graph_from_dot_data(dot_data.getvalue())
#       4 Image(graph.create_png())
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pydot.pyc in graph_from_dot_data(data)
#     197     """
#     198
# --> 199     return dot_parser.parse_dot_data(data)
#     200
#     201
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/dot_parser.pyc in parse_dot_data(data)
#     468             graphparser.parseWithTabs()
#     469
# --> 470         tokens = graphparser.parseString(data)
#     471
#     472         if len(tokens) == 1:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseString(self, instring, parseAll)
#     994             instring = instring.expandtabs()
#     995         try:
# --> 996             loc, tokens = self._parse( instring, 0 )
#     997             if parseAll:
#     998                 loc = self.preParse( instring, loc )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2740     def parseImpl( self, instring, loc, doActions=True ):
#    2741         # must be at least one
# -> 2742         loc, tokens = self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2743         try:
#    2744             hasIgnoreExprs = ( len(self.ignoreExprs) > 0 )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2340                     raise ParseSyntaxException( ParseException(instring, len(instring), self.errmsg, self) )
#    2341             else:
# -> 2342                 loc, exprtokens = e._parse( instring, loc, doActions )
#    2343             if exprtokens or exprtokens.keys():
#    2344                 resultlist += exprtokens
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2594     def parseImpl( self, instring, loc, doActions=True ):
#    2595         if self.expr is not None:
# -> 2596             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2597         else:
#    2598             raise ParseException("",loc,self.errmsg,self)
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2340                     raise ParseSyntaxException( ParseException(instring, len(instring), self.errmsg, self) )
#    2341             else:
# -> 2342                 loc, exprtokens = e._parse( instring, loc, doActions )
#    2343             if exprtokens or exprtokens.keys():
#    2344                 resultlist += exprtokens
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2790     def parseImpl( self, instring, loc, doActions=True ):
#    2791         try:
# -> 2792             loc, tokens = self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2793         except (ParseException,IndexError):
#    2794             if self.defaultValue is not _optionalNotMatched:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2594     def parseImpl( self, instring, loc, doActions=True ):
#    2595         if self.expr is not None:
# -> 2596             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2597         else:
#    2598             raise ParseException("",loc,self.errmsg,self)
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2748                 else:
#    2749                     preloc = loc
# -> 2750                 loc, tmptokens = self.expr._parse( instring, preloc, doActions )
#    2751                 if tmptokens or tmptokens.keys():
#    2752                     tokens += tmptokens
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2324         # pass False as last arg to _parse for first element, since we already
#    2325         # pre-parsed the string as part of our And pre-parsing
# -> 2326         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    2327         errorStop = False
#    2328         for e in self.exprs[1:]:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2449         for e in self.exprs:
#    2450             try:
# -> 2451                 ret = e._parse( instring, loc, doActions )
#    2452                 return ret
#    2453             except ParseException, err:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2324         # pass False as last arg to _parse for first element, since we already
#    2325         # pre-parsed the string as part of our And pre-parsing
# -> 2326         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    2327         errorStop = False
#    2328         for e in self.exprs[1:]:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2594     def parseImpl( self, instring, loc, doActions=True ):
#    2595         if self.expr is not None:
# -> 2596             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2597         else:
#    2598             raise ParseException("",loc,self.errmsg,self)
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2594     def parseImpl( self, instring, loc, doActions=True ):
#    2595         if self.expr is not None:
# -> 2596             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2597         else:
#    2598             raise ParseException("",loc,self.errmsg,self)
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2449         for e in self.exprs:
#    2450             try:
# -> 2451                 ret = e._parse( instring, loc, doActions )
#    2452                 return ret
#    2453             except ParseException, err:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2340                     raise ParseSyntaxException( ParseException(instring, len(instring), self.errmsg, self) )
#    2341             else:
# -> 2342                 loc, exprtokens = e._parse( instring, loc, doActions )
#    2343             if exprtokens or exprtokens.keys():
#    2344                 resultlist += exprtokens
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2790     def parseImpl( self, instring, loc, doActions=True ):
#    2791         try:
# -> 2792             loc, tokens = self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2793         except (ParseException,IndexError):
#    2794             if self.defaultValue is not _optionalNotMatched:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2449         for e in self.exprs:
#    2450             try:
# -> 2451                 ret = e._parse( instring, loc, doActions )
#    2452                 return ret
#    2453             except ParseException, err:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2594     def parseImpl( self, instring, loc, doActions=True ):
#    2595         if self.expr is not None:
# -> 2596             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2597         else:
#    2598             raise ParseException("",loc,self.errmsg,self)
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     869             if self.mayIndexError or loc >= len(instring):
#     870                 try:
# --> 871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#     873                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    2324         # pass False as last arg to _parse for first element, since we already
#    2325         # pre-parsed the string as part of our And pre-parsing
# -> 2326         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    2327         errorStop = False
#    2328         for e in self.exprs[1:]:
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#     926         else:
#     927             try:
# --> 928                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#     929                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#     930                 return value
#
# /Users/Tian/anaconda/lib/python2.7/site-packages/pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     868             tokensStart = preloc
#     869             if self.mayIndexError or loc >= len(instring):
# --> 870                 try:
#     871                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     872                 except IndexError:
#
# KeyboardInterrupt:
